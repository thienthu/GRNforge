# %%
import sys
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import pickle
import gzip
import anndata as ad
# %matplotlib inline
# now, make regression
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import sklearn.metrics
import scanpy as sc

# %%
def loadSCENICResult(path, genes=None, min_regulon_size= 1, weights=None):
    """
    Helper function to load the scenig result (zero-one file for all TF-targets per regulon)
    Carefull: colnames can be duplicate gene names, depending on which motifs were found 
    """
    weight_dic = {}
    # load and process weights
    #print("WHy does it not print???")
    if weights != None:
        df_w = pd.read_csv(weights,sep='\t')
        for TF, TG, W in zip(df_w['TF'], df_w['target'],df_w['importance']):
            weight_dic[TF+'~'+TG] = W
           # print(TF+'~'+TG,  W)

    # Load GRN
    GRN_full_df =  pd.read_csv(path, sep=',', index_col = 0)

    # get all Regulon names
    TF_names = {}
    for i in list(GRN_full_df.columns):
        if i != 'regulonMatrix.gene' and i != 'genes':
            TF_names[i] = i.replace('regulonMatrix.', '').split('_')[0]
    
    # clean up wrong column names:
    if 'gene' in TF_names:
        del TF_names['gene']
    
    #print(TF_names)
    TF_TG_interactions          = {}
    TF_TG_interactions_weighted = {}
    
    if genes != None:
        for i in TF_names:
            interactions  = []
            status        = []
            weight_list   = []
            for index, row in GRN_full_df[i].items():
#                return
#                # make a filter step to check whether gene name is present in dataframe
                if index in genes:
                    interactions.append(TF_names[i]+'~'+index)
                    status.append(abs(int(row)))
                    if weights!= None:
                        if TF_names[i]+'~'+index in weight_dic:
                            weight_list.append(weight_dic[TF_names[i]+'~'+index])
                        else:
                             weight_list.append(0)
                
            # add a regulon size filter at this position, setting a minimum amount of edges per regulon
            df = pd.DataFrame(list(zip(interactions, status)), columns =['Interaction', 'Status'])
            df_2 = pd.DataFrame(list(zip(interactions, weight_list)), columns =['Interaction', 'weight_list'])
            if len(df[df['Status'] > 0]) >= min_regulon_size:
                TF_TG_interactions[TF_names[i]] = pd.DataFrame(list(zip(interactions, status)), columns =['Interaction', 'Status'])
                if weights!= None:
                    TF_TG_interactions_weighted[TF_names[i]] = pd.DataFrame(list(zip(interactions, weight_list)), columns =['Interaction', 'Status'])
    else:
        for i in TF_names:
            #print(i)
            interactions  = []
            status        = []
            weight_list   = []
            for index, row in GRN_full_df[i].items():
                interactions.append(TF_names[i]+'~'+index)
                status.append(abs(int(row)))
                if weights!= None:
                    if TF_names[i]+'~'+index in weight_dic:
                        weight_list.append(weight_dic[TF_names[i]+'~'+index])
                    else:
                        weight_list.append(0)
            #print(len(interactions), len(status), len(weight_list))  
            # add a regulon size filter at this position, setting a minimum amount of edges per regulon
            df = pd.DataFrame(list(zip(interactions, status)), columns =['Interaction', 'Status'])
            df_2 = pd.DataFrame(list(zip(interactions, status)), columns =['Interaction', 'weight_list'])
            if len(df[df['Status'] > 0]) >= min_regulon_size:
                TF_TG_interactions[TF_names[i]] = pd.DataFrame(list(zip(interactions, status)), columns =['Interaction', 'Status'])
                if weights!= None:
                    TF_TG_interactions_weighted[TF_names[i]] = pd.DataFrame(list(zip(interactions, weight_list)), columns =['Interaction', 'Status'])
    #print(TF_TG_interactions_weighted)

    return TF_TG_interactions, TF_TG_interactions_weighted

def intersection(lst1, lst2):
    lst2 = dict.fromkeys(lst2, [])
    lst3 = [value for value in lst1 if value in lst2]
    return lst3

def intersect_pf(Regulon_to_compare, ChIP_gold_df):
    """
    The goal of this function is to intersect entries that were consideret inthe inferred networks with interations present in the gold standard
    Also remove duplicates, in case they could appear for some reason in the Gold Standard.
    The function works because both dataframes have ALL possible interactions realised, meaning each TG-TF pair that was measured
    or was in the gold standard has an id (and can be 0 or 1, whether it exists or not).
    Each regulon TF in a sample is therefore compared to the gold standard for ALL possible gene interactions. 
    The filtered out interactions with genes that were not measured in the gold standard, or were not measured in the dataset 
    """
    # Drop dupliate interactions (normally they do not exist)
    Regulon_to_compare.drop_duplicates(subset=['Interaction'], inplace = True)
    ChIP_gold_df.drop_duplicates(subset=['Interaction'], inplace = True)
    # Get interactions of the same id's
    same_ids = intersection(list(Regulon_to_compare['Interaction']),list(ChIP_gold_df['Interaction']))
    #print("check stats:", len(same_ids))
    #print(list(Regulon_to_compare['Interaction']))
    #print(ChIP_gold_df['Interaction'])
    I_TG =  Regulon_to_compare[Regulon_to_compare['Interaction'].isin(same_ids)] 
    I_Gold =  ChIP_gold_df[ChIP_gold_df['Interaction'].isin(same_ids)] 
    
    # sort both datasets, so that the index of an interaction is the same between both
    I_TG   = I_TG.sort_values(by=['Interaction'], ignore_index=True, inplace=False)
    I_Gold = I_Gold.sort_values(by=['Interaction'],  ignore_index=True, inplace=False)
    
    return I_TG,I_Gold


def prepareCollecTRIGoldStandard(path, evidence_score=1, complex_filter = 'complex_removed'):
    """
    Function to load CollecTRI, filter it based on evidence, and return two gold standards: Full and filtered.
    For complex_filter, one can set all (no filtering), complex_only (only complexes), complex_removed (only non 
    complex interactions)
    """
    # load CollecTRI into pandas dataframe
    CTRI              = pd.read_csv(path,sep='\t')
    # annotate whether an interaction is a complex (allows to remove them later)
    complex_indicator = [True if 'COMPLEX' in i else False for i in list(CTRI['source'])]
    CTRI['is_complex'] = complex_indicator

    # Test filter
    if complex_filter == 'complex_only':
        CTRI = CTRI[ CTRI['is_complex'] == True]
    elif complex_filter == 'complex_removed':
        CTRI = CTRI[ CTRI['is_complex'] == False]
    else:
        CTRI = CTRI
    
    # Make gold standard for unfiltered case:
    # Get TG and TF names
    TFs = {}
    TGs = {}
    for i in CTRI['source']:
        TFs[i] = []
    for i in CTRI['target']:
        TGs[i] = []    

    for i in list(zip(CTRI['source'], CTRI['target'])):
        TFs[i[0]].append(i[1])
        
    #print(TFs)
    
    # Ceate TF-TG interaction dataframes for all
    TF_TG_interactions_full = {}
    for TF in TFs:
        interaction_list = []
        status_list      = []
       # print(TF)
        
        for TG in TGs:         
            if TG in TFs[TF]:
                interaction_list.append(TF+'~'+TG)
                status_list.append(1)
            else:
                interaction_list.append(TF+'~'+TG)
                status_list.append(0)
        TF_TG_interactions_full[TF] = pd.DataFrame(list(zip(interaction_list, status_list)), columns =['Interaction', 'Status'])
    #print(TF_TG_interactions_full)

    # Make gold standard for filtered case:
    CTRI = CTRI[CTRI['curation_effort'] >= evidence_score]
    
    # Get TG and TF names
    TFs = {}
    TGs = {}
    for i in CTRI['source']:
        TFs[i] = []
    for i in CTRI['target']:
        TGs[i] = []    

    for i in list(zip(CTRI['source'], CTRI['target'])):
        TFs[i[0]].append(i[1])
    
    # Ceate TF-TG interaction dataframes for all
    TF_TG_interactions_filtered = {}
    for TF in TFs:
        interaction_list = []
        status_list      = []

        for TG in TGs:
            if TG in TFs[TF]:
                interaction_list.append(TF+'~'+TG)
                status_list.append(1)
            else:
                interaction_list.append(TF+'~'+TG)
                status_list.append(0)
        TF_TG_interactions_filtered[TF] = pd.DataFrame(list(zip(interaction_list, status_list)), columns =['Interaction', 'Status'])

    
        
    return(TF_TG_interactions_full, TF_TG_interactions_filtered)


def normalizeImportanceScores(scores, top_k_threshold=None, scaling_factor=100):
    """
    Take all importance scores, and rank them by their relative contribution with regard to 
    the total sum of importance scores.
    """
    new_scores = scores.copy()
    for TG in scores:
        if top_k_threshold == None:
            sum_over_scores = np.sum(list(scores[TG].values()))
        else:
            sum_over_scores = np.sum(sorted(list(scores[TG].values()), reverse=True)[:top_k_threshold]) 
        for TF in scores[TG]:
            new_scores[TG][TF] = (scores[TG][TF]/sum_over_scores)*scaling_factor
    return new_scores

def normalizeForModelPerformance(scores, performance, scaling_factor=1, score_type=1):
    """
    Take all importance scores, and multiply them by a factor that represents
    the [0-1] scaled model performance. Model performance is calcuated relatively to offset the different
    expression ranges by validating it against a mean baseline (mae_prediction/mean_TG)
    The performance dictionary contains tuples of (mean, train_error, test_error)
    """
    new_scores = scores.copy()

    # prepare model scaling factor
    error             = []
    mean              = []
    error_mean_ratio  = {}
    for i in performance:
        #if performance[i][0]:
        mean.append(performance[i][0])
        error.append(performance[i][1]) 
        error_mean_ratio[i] = error[-1]/mean[-1]   # if error < mean, the coefficient is < 1

    # Divide each error_mean_ratio by the maxium mean_error ration.
    # Then build the inverse, as the lower values indicate better performance
    max_error_mean_ratio = max(error_mean_ratio.values())
    
    for TG in error_mean_ratio:
        error_mean_ratio[TG] =  1-(error_mean_ratio[TG]/max_error_mean_ratio)    
    
    for TG in scores:
        for TF in scores[TG]:
            new_scores[TG][TF] = scores[TG][TF] * error_mean_ratio[TG]
    return new_scores




def makePandasNetwork(regulons, interactions):
    """
    Use on regulons and interactions to create a data structure: 
    Dictionary with TFs as keys and pandas DataFrame of all TGs
    Two columns: Interactions [TF~TG] and Status. Status takes 0 or 1 for binary indication of an edge, or the weight of the edge.
    """
    # Create TF_TG_interactions_binary and TF_TG_interactions_weighted
    #all_target_genes = set(TG for _, TG, _ in selected_interactions)
    all_target_genes = set([x.split('~')[1] for x in  list(interactions.keys())])
    
    TF_TG_interactions_binary = {}
    TF_TG_interactions_weighted = {}

    for TF, tg_dict in regulons.items():
        # Prepare the interaction and status lists
        interaction_list = []
        status_binary_list = []
        status_weighted_list = []

        # Iterate over all target genes to build interaction keys and status
        for target_gene in all_target_genes:
            interaction_key = f"{TF}~{target_gene}"
            interaction_list.append(interaction_key)

            # For binary interaction (1 if interaction exists, 0 if not)
            status_binary = 1 if interaction_key in interactions else 0
            status_binary_list.append(status_binary)

            # For weighted interaction (importance score)
            status_weighted = tg_dict.get(target_gene, 0)
            status_weighted_list.append(status_weighted)

        # Create DataFrames
        TF_TG_interactions_binary[TF] = pd.DataFrame({
            'Interaction': interaction_list,
            'Status': status_binary_list
        })

        TF_TG_interactions_weighted[TF] = pd.DataFrame({
            'Interaction': interaction_list,
            'Status': status_weighted_list
        })    

    return TF_TG_interactions_binary, TF_TG_interactions_weighted


def makeCustomNetwork(scores, minimum_regulon_size=10, number_edges=100000, verbose=True):
    """
    Make a custom network based on the XGBoost scores.
    """
    # Reverse dictionary structure: TG -> {TF: score} -> TF -> {TG: score}
    inital_interactions = []
    
    for TG, tf_dict in scores.items():
        for TF, score in tf_dict.items():
            inital_interactions.append((TF, TG, score))

    # Sort all interactions by score (descending)
    inital_interactions.sort(key=lambda x: x[2], reverse=True)

    if verbose:
        print(f"Total initial interactions: {len(inital_interactions)}")

    # Ensure we do not exceed available edges
    number_edges = min(number_edges, len(inital_interactions))

    # Find the threshold score at position `number_edges`
    thres = inital_interactions[number_edges - 1][2]  # (TF, TG, score) → score

    if verbose:
        print(f"Threshold: {thres}")

    # Collect exactly `number_edges` edges, handling ties deterministically
    selected_interactions = []
    for TF, TG, score in inital_interactions:
        if len(selected_interactions) >= number_edges:
            break
        if score > thres or (score == thres and len(selected_interactions) < number_edges):
            selected_interactions.append((TF, TG, score))

    if verbose:
        print(f"Final edge count: {len(selected_interactions)}")

    # Convert back to TF -> {TG: score} structure
    regulons = {}
    interactions = {}
    
    for TF, TG, score in selected_interactions:
        regulons.setdefault(TF, {})[TG] = score
        interactions[f"{TF}~{TG}"] = score

    # Remove small regulons
    regulons = {TF: tg_dict for TF, tg_dict in regulons.items() if len(tg_dict) >= minimum_regulon_size}
    
    # create weighted and binary pandas dataframes
    TF_TG_interactions_binary, TF_TG_interactions_weighted = makePandasNetwork(regulons, interactions)
        
    return regulons, interactions, TF_TG_interactions_binary, TF_TG_interactions_weighted


def rank_dict_values(interactions):
    """
    Replace values in a dictionary with their rank.
    The highest value gets the highest numerical rank.
    """
    sorted_items = sorted(interactions.items(), key=lambda x: x[1], reverse=False)
    ranks = {key: rank+1 for rank, (key, _) in enumerate(sorted_items)}
    return ranks


def rankIntegration(list_interactions, mode='maxrank', interactions = 20000, minimum_regulon_size = 10, verbose=False):
    """
    Function to integrate two or more networks based on the rank of interactions. Differernt integration modes are:
    maxrank:    Per interaction, take the maximum rank across all networks => This mode preserves best individual high ranks between networks
    meanrank:   This gives an option to downrank/uprank a gene based on consensus mean
    medianrank: This gives an option to downrank/uprank a gene based on consensus median
    minrank:    A meme implementation for test reasons. Expected to give you the worst network in comparison
    boostrank:  Tries to given an advantage ot edges that were found in multiple models. Same as meanrank, but considers the worsed rank for
                edges that do not exist in one model

    Input:  list_interactions
    Output: regulons_integrated, interactions_integrated, TF_TG_interactions_binary, TF_TG_interactions_weighted
    """

    # get all possible interactions 
    all_possible_interactions = set()
    for network in list_interactions:
        all_possible_interactions.update(set(list(network.keys())))

    ranked_networks = []
    # calculate ranks (lowest rank = highest value)
    for network in list_interactions:
        ranked_networks.append( rank_dict_values(network) )

    integrated_interactions = {}
    # start the integration
    for interaction in all_possible_interactions:
        if mode == 'maxrank':
            ranks = []
            for network in ranked_networks:
                if interaction in network:
                    ranks.append(network[interaction])
            integrated_interactions[interaction] = max(ranks)
        if mode == 'minrank':
            ranks = []
            for network in ranked_networks:
                if interaction in network:
                    ranks.append(network[interaction])
            integrated_interactions[interaction] = min(ranks)
        if mode == 'meanrank':
            ranks = []
            for network in ranked_networks:
                if interaction in network:
                    ranks.append(network[interaction])
            integrated_interactions[interaction] = np.mean(ranks)
        if mode == 'medianrank':
            ranks = []
            for network in ranked_networks:
                if interaction in network:
                    ranks.append(network[interaction])
            integrated_interactions[interaction] = np.median(ranks)
        if mode == 'boostrank':
            ranks = []
            for network in ranked_networks:
                if interaction in network:
                    ranks.append(network[interaction])
                else:
                    ranks.append(1)
            integrated_interactions[interaction] = np.mean(ranks)

    #print(integrated_interactions)
    # prune edges to desired number if necessary
    if interactions == 'all':
        interactions = len(integrated_interactions)

    # Collect exactly `number_edges` edges, handling ties deterministically


    if verbose:
        print(f"Total initial interactions: {len(inital_interactions)}")

    # Ensure we do not exceed available edges
    number_edges = min(interactions, len(integrated_interactions))

    # Find the threshold score at position `number_edges`
    thres = sorted(list(integrated_interactions.values()), reverse=True)[interactions - 1]  # (TF, TG, score) → score
    #print(sorted(list(integrated_interactions.values()), reverse=True))
    print(thres)
    selected_interactions = []
    for edge in integrated_interactions:
        TF = edge.split('~')[0]
        TG = edge.split('~')[1]
        score = integrated_interactions[edge]
        #print(TF, TG, score)
        if len(selected_interactions) >= number_edges:
            break
        if score > thres:# or (score == thres and len(integrated_interactions) < number_edges):
            selected_interactions.append((TF, TG, score))
        
    #print(selected_interactions)
    if verbose:
        print(f"Final edge count: {len(selected_interactions)}")

    # Convert back to TF -> {TG: score} structure
    regulons = {}
    interactions = {}
    
    for TF, TG, score in selected_interactions:
        regulons.setdefault(TF, {})[TG] = score
        interactions[f"{TF}~{TG}"] = score

    # Remove small regulons
    regulons = {TF: tg_dict for TF, tg_dict in regulons.items() if len(tg_dict) >= minimum_regulon_size}
    
    # create weighted and binary pandas dataframes
    TF_TG_interactions_binary, TF_TG_interactions_weighted = makePandasNetwork(regulons, interactions)
    # get regulons from integrated_interactions:
    return regulons, interactions, TF_TG_interactions_binary , TF_TG_interactions_weighted       
    
    
regulons_int, interactions_int, TF_TG_interactions_binary_int, TF_TG_interactions_weighted_int  =rankIntegration([interactions_exp_exp, interactions_act_act])
# Out:
# 9895

# %%
len(interactions_int)
# Out:
# 19999

# %%
type([interactions_exp_exp][0])
# Out:
# dict

# %%
# lets start with loading the XGBoost outputs first

base_result_path = '/scratch/gent/vo/000/gvo00027/projects/CBIGR/24JLR_GRN/results/human_PBMC_10x_10k/GRN_test_runs/'
run_name         = 'run_1/'

# train all models 
TG_models_exp_exp_scores            = {}
TG_models_exp_exp_evals             = {}
TG_models_exp_exp_pred_performance  = {}

TG_models_act_act_scores            = {}
TG_models_act_act_evals             = {}
TG_models_act_act_pred_performance  = {}

TG_models_exp_act_scores            = {}
TG_models_exp_act_evals             = {}
TG_models_exp_act_pred_performance  = {}

TG_models_act_exp_scores            = {}
TG_models_act_exp_evals             = {}
TG_models_act_exp_pred_performance  = {}

path = base_result_path+run_name+'/model_exp_exp/'

with gzip.open(path+'/baseline_model_1_scores.pkl', 'rb') as handle:
    TG_models_exp_exp_scores = pickle.load(handle)
with gzip.open(path+'/baseline_model_1_evals.pkl', 'rb') as handle:
    TG_models_exp_exp_evals = pickle.load(handle)
with gzip.open(path+'/baseline_model_1_predictive_performance.pkl', 'rb') as handle:
    TG_models_exp_exp_pred_performance = pickle.load(handle)

path = base_result_path+run_name+'/model_act_act/'

with gzip.open(path+'/baseline_model_1_scores.pkl', 'rb') as handle:
    TG_models_act_act_scores = pickle.load(handle)
with gzip.open(path+'/baseline_model_1_evals.pkl', 'rb') as handle:
    TG_models_act_act_evals = pickle.load(handle)
with gzip.open(path+'/baseline_model_1_predictive_performance.pkl', 'rb') as handle:
    TG_models_act_act_pred_performance = pickle.load(handle)

# %%
#TG_models_exp_exp_scores['BRCA2']
TG_models_exp_exp_pred_performance['BRCA2']
#TG_models_act_act_pred_performance['BRCA2']
# lets invesitgare first, how mean and model quality are related
# Out:
# (1.177608989699303, 0.8253977198413458, 0.9408668057718936)

# %%
error             = []
mean              = []
error_mean_ratio  = []
for i in TG_models_exp_exp_pred_performance:
    if TG_models_exp_exp_pred_performance[i][0]:
        mean.append(TG_models_exp_exp_pred_performance[i][0])
        error.append(TG_models_exp_exp_pred_performance[i][1])
        error_mean_ratio.append(error[-1]/mean[-1])   # if error < mean, the coefficient is < 1

# %%
sns.scatterplot(y=error, x=mean)
# Out:
# <Axes: >

# %%
from scipy.stats import pearsonr

corr, p_value = pearsonr(error, mean)
print(f"Pearson correlation: {corr:.4f}, p-value: {p_value:.4e}")
# Out:
# Pearson correlation: 0.8044, p-value: 0.0000e+00

# %%
from scipy.stats import spearmanr

corr, p_value = spearmanr(error, mean)
print(f"Pearson correlation: {corr:.4f}, p-value: {p_value:.4e}")
# Out:
# Pearson correlation: 0.9976, p-value: 0.0000e+00

# %%
sns.histplot(error_mean_ratio)
# Out:
# <Axes: ylabel='Count'>

# %%
# now, apply within-model and across-model normalization
new_scores     = normalizeImportanceScores(TG_models_exp_exp_scores, top_k_threshold=30)
new_scores_all = normalizeForModelPerformance(new_scores, TG_models_exp_exp_pred_performance)
# Make a network
regulons_exp_exp, interactions_exp_exp, TF_TG_interactions_binary_exp_exp, TF_TG_interactions_weighted_exp_exp = makeCustomNetwork(new_scores_all, minimum_regulon_size=10, number_edges=20000, verbose=True)
print(len(regulons_exp_exp), len(interactions_exp_exp))
regulons_exp_exp_30k = regulons_exp_exp.copy()
# Out:
# /tmp/ipykernel_726238/2977927367.py:231: RuntimeWarning: invalid value encountered in scalar divide
#   error_mean_ratio[i] = error[-1]/mean[-1]   # if error < mean, the coefficient is < 1
# Total initial interactions: 1999356
# Threshold: 3.2625687805674493
# Final edge count: 20000
# 319 20000

# %%
sum(TF_TG_interactions_weighted['RUNX1']['Status'])
# Out:
# 781.5906198439862

# %%
sum(regulons_exp_exp['RUNX1'].values())
# Out:
# 781.5906198439868

# %%
reg_size = []
TGs      = []
for TF in regulons_exp_exp:
    reg_size.append(len(regulons_exp_exp[TF]))
    TGs.extend(list(regulons_exp_exp[TF].keys()))
TGs = set(TGs)
print(len(TGs))
# Out:
# 7556

# %%
sns.histplot(reg_size)
# Out:
# <Axes: ylabel='Count'>

# %%
print(np.mean(reg_size))
print(np.median(reg_size))
# Out:
# 61.38557993730407
# 38.0

# %%
len(interactions_exp_exp)
# Out:
# 20000

# %%
# Lets do the same for the act_act network
# now, apply within-model and across-model normalization
new_scores     = normalizeImportanceScores(TG_models_act_act_scores, top_k_threshold=30)
new_scores_all = normalizeForModelPerformance(new_scores, TG_models_act_act_pred_performance)
regulons_act_act, interactions_act_act, TF_TG_interactions_binary_act_act, TF_TG_interactions_weighted_act_act= makeCustomNetwork(new_scores_all, minimum_regulon_size=10, number_edges=20000)
# Out:
# /tmp/ipykernel_726238/4150534741.py:115: RuntimeWarning: invalid value encountered in scalar divide
#   error_mean_ratio[i] = error[-1]/mean[-1]   # if error < mean, the coefficient is < 1
# Total initial interactions: 3411308
# Threshold: 2.227677611736997
# Final edge count: 20000

# %%
reg_size = []
TGs      = []
for TF in regulons_act_act:
    reg_size.append(len(regulons_act_act[TF]))
    TGs.extend(list(regulons_act_act[TF].keys()))
TGs = set(TGs)
print(len(TGs))
# Out:
# 2406

# %%
sns.histplot(reg_size)
# Out:
# <Axes: ylabel='Count'>

# %%
print(np.mean(reg_size))
print(np.median(reg_size))
# Out:
# 44.13378684807256
# 24.0

# %%
len(interactions_act_act)
# Out:
# 20000

# %%
# Quick check on how many interactions end up overlapping across different test tresholds:
len(set(interactions_act_act.keys()).intersection(set(interactions_exp_exp.keys())))
# Out:
# 428

# %%
overlap_edges        = []
TFs_act              = []
TGs_act              = []
TFs_exp              = []
TGs_exp              = []
reg_size_median_exp  = []
reg_size_median_act  = []

for i in [1000, 5000, 10000, 20000, 30000, 40000, 50000, 100000]:
    # now, apply within-model and across-model normalization
    new_scores     = normalizeImportanceScores(TG_models_exp_exp_scores, top_k_threshold=30)
    new_scores_all = normalizeForModelPerformance(new_scores, TG_models_exp_exp_pred_performance)
    # Make a network
    regulons_exp_exp, interactions_exp_exp, _, _ = makeCustomNetwork(new_scores_all, minimum_regulon_size=10, number_edges=i, verbose=False)    

    # Lets do the same for the act_act network
    # now, apply within-model and across-model normalization
    new_scores     = normalizeImportanceScores(TG_models_act_act_scores, top_k_threshold=30)
    new_scores_all = normalizeForModelPerformance(new_scores, TG_models_act_act_pred_performance)
    regulons_act_act, interactions_act_act, _, _ = makeCustomNetwork(new_scores_all, minimum_regulon_size=10, number_edges=i, verbose=False)

    reg_size = []
    TGs      = []
    for TF in regulons_exp_exp:
        reg_size.append(len(regulons_exp_exp[TF]))
        TGs.extend(list(regulons_exp_exp[TF].keys()))
    TFs_exp.append(len(regulons_exp_exp))
    TGs_exp.append(len(set(TGs)))
    reg_size_median_exp.append(np.mean(reg_size))

    reg_size = []
    TGs      = []
    for TF in regulons_act_act:
        reg_size.append(len(regulons_act_act[TF]))
        TGs.extend(list(regulons_act_act[TF].keys()))
    TFs_act.append(len(regulons_act_act))
    TGs_act.append(len(set(TGs)))
    reg_size_median_act.append(np.mean(reg_size))

    overlap_edges.append(len(set(interactions_act_act.keys()).intersection(set(interactions_exp_exp.keys()))))
# Out:
# /tmp/ipykernel_726238/3352516016.py:115: RuntimeWarning: invalid value encountered in scalar divide
#   error_mean_ratio[i] = error[-1]/mean[-1]   # if error < mean, the coefficient is < 1

# %%
# Create a dictionary to structure the data
data = {
    "Overlap Edges": overlap_edges,
    "TFs (Activity)": TFs_act,
    "TGs (Activity)": TGs_act,
    "TFs (Expression)": TFs_exp,
    "TGs (Expression)": TGs_exp,
    "Regulon Size (Median, Expression)": reg_size_median_exp,
    "Regulon Size (Median, Activity)": reg_size_median_act
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Set up the figure and axes
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(12, 10))
axes = axes.flatten()

# Create line plots
for i, (key, values) in enumerate(data.items()):
    sns.lineplot(ax=axes[i], data=df, x=[1000, 5000, 10000, 20000, 30000, 40000, 50000, 100000], y=key)
    axes[i].set_title(key)
    axes[i].set_xlabel("Index")
    axes[i].set_ylabel("Value")

# Adjust layout
plt.tight_layout()
plt.show()

# %%
overlap_edges
# Out:
# [23, 107, 210, 428, 724, 953, 1183, 2873]

# %%
regulons_t['FOS']
# Out:
# {'HMGN2': 5.635930418346335,
#  'SEC31A': 4.491943587110351,
#  'SP2': 4.1399988861088515,
#  'TLE4': 3.9676831154742156,
#  'TRMT112': 3.5554795469736957,
#  'FKBP1A': 3.345930672778929,
#  'SIRT2': 3.2339707265222195,
#  'EIF1': 3.2245350950165554,
#  'IGSF1': 3.0901924425440526,
#  'SETD3': 3.0880577259276256,
#  'KIAA0100': 3.0603115151917746,
#  'CRYZL1': 3.019506179339319,
#  'OIP5-AS1': 2.9674310534795545,
#  'MYPOP': 2.9462728579502024,
#  'LIN37': 2.9111645140270257,
#  'AP2B1': 2.826048307316483,
#  'DSTN': 2.769066085126973,
#  'MEPCE': 2.7097261971917748,
#  'NTMT1': 2.6743674178523915,
#  'GNAI2': 2.6273555683085346,
#  'OSBP': 2.6272119603064494,
#  'HLA-C': 2.6225358567902526,
#  'GRAMD1A': 2.608248506653615,
#  'INO80': 2.541133317685746,
#  'SLC33A1': 2.4716063676066615,
#  'LINC00205': 2.45821626021624,
#  'CCNYL1': 2.388876833856705,
#  'KANSL1': 2.366301459491038,
#  'DNAI1': 2.360029510000313,
#  'C1orf35': 2.3598161169559058,
#  'MCL1': 2.3473987460400028,
#  'ZMAT3': 2.3430523954545635,
#  'KDM4A-AS1': 2.323587198202649,
#  'CNR1': 2.3008087376678983,
#  'SNRPD2': 2.2614265758023486,
#  'ZBTB37': 2.2333171907324756,
#  'DKC1': 2.228555980284733}

# %%
regulons_exp_exp.keys()
# Out:
# dict_keys(['ZNF263', 'RUNX1', 'CREB5', 'ZNF329', 'REL', 'IRF8', 'ZEB1', 'NR3C2', 'E2F5', 'BCL11B', 'IRF1', 'ZBTB49', 'CEBPD', 'RXRA', 'TCF12', 'MEF2C', 'BCL6', 'GABPA', 'GATA3', 'POU2F2', 'PAX8', 'KLF4', 'SP140', 'SP1', 'HOXB2', 'PKNOX1', 'POU2F1', 'REST', 'RFX3', 'PAX5', 'ZNF431', 'EBF1', 'PBX4', 'CTCF', 'ZBTB7A', 'CUX2', 'KLF10', 'CLOCK', 'FLI1', 'ZNF652', 'SPI1', 'ELK4', 'ETV6', 'ETV3', 'MAFB', 'ZNF708', 'IRF9', 'BATF', 'ZNF382', 'JUND', 'NR6A1', 'SRF', 'ERF', 'HIF1A', 'NR3C1', 'ESRRA', 'AHR', 'HOXB4', 'OVOL2', 'NRL', 'SP100', 'FOS', 'ZNF331', 'ZNF148', 'CREBZF', 'MECOM', 'MAFG', 'HIVEP1', 'PRDM4', 'BACH2', 'BACH1', 'XBP1', 'STAT2', 'ESR1', 'LEF1', 'TGIF2', 'NR1D1', 'CUX1', 'JDP2', 'JUNB', 'PPARD', 'TFEB', 'MAX', 'NFKB2', 'ELF2', 'ZNF8', 'NFIC', 'FOXJ3', 'ZBTB16', 'ELK1', 'PBX2', 'E2F6', 'RARA', 'NRF1', 'CREB3L2', 'FOXN3', 'STAT5B', 'HOMEZ', 'ZNF146', 'ATF3', 'FOSB', 'TCF7L2', 'HSF2', 'MEF2D', 'JUN', 'RUNX3', 'RELA', 'TCF4', 'ATF4', 'KLF13', 'KLF9', 'BHLHE40', 'CDC5L', 'SMAD2', 'IRF2', 'HIVEP2', 'NFIX', 'KLF2', 'ZNF76', 'TP53', 'ELF1', 'MXI1', 'KLF7', 'IKZF1', 'KLF16', 'ETS1', 'DBP', 'MYBL1', 'ZKSCAN1', 'RUNX2', 'RFX7', 'HIVEP3', 'ZNF75A', 'MITF', 'ZNF75D', 'ELK3', 'PATZ1', 'CREB1', 'STAT3', 'BBX', 'ZNF143', 'NFKB1', 'STAT5A', 'CEBPB', 'ZNF281', 'RORA', 'ZNF257', 'PRDM1', 'TBX21', 'ZNF816', 'KLF12', 'CREM', 'GZF1', 'NFATC3', 'SPIB', 'ATF2', 'NFAT5', 'ZNF467', 'ZNF586', 'ZNF628', 'TCF7', 'ETS2', 'E2F3', 'PPARA', 'ZFP82', 'ZNF680', 'MYC', 'ZNF394', 'ZNF322', 'ETV7', 'IRF7', 'NR2F6', 'YY1', 'SP4', 'ZKSCAN4', 'ZNF740', 'PURA', 'IKZF3', 'TFDP2', 'RFX1', 'ATF6', 'SP3', 'ZNF274', 'ZBTB14', 'THAP11', 'ZBED1', 'NFIL3', 'TFCP2', 'BCL11A', 'RFX5', 'HES4', 'ZNF528', 'KLF6', 'ZNF713', 'ZNF549', 'NFE2', 'MEF2A', 'STAT4', 'MAF', 'ZBTB4', 'TGIF1', 'E4F1', 'VENTX', 'ZBTB33', 'ZNF524', 'CREB3', 'GMEB2', 'THRA', 'CEBPG', 'ZNF490', 'RFX2', 'ZNF563', 'ZNF41', 'NFYC', 'NR1D2', 'UBP1', 'STAT1', 'ZNF784', 'ZNF264', 'SMAD3', 'ZBTB18', 'TFAP4', 'ZNF768', 'RREB1', 'NFYB', 'EGR1', 'SMAD4', 'FOXK2', 'MGA', 'NR1H2', 'FOXN2', 'NFE2L1', 'FOXO1', 'RBPJ', 'SREBF2', 'NFIA', 'KLF3', 'NFATC1', 'ATF6B', 'PBX3', 'ARNT', 'ATF7', 'ATF1', 'ZNF324', 'DDIT3', 'SP2', 'ZNF136', 'TFE3', 'ATF5', 'E2F4', 'MAZ', 'ZNF24', 'RELB', 'FOSL1', 'HINFP', 'FOSL2', 'ZNF121', 'NR2C2', 'NR2C1', 'ZNF683', 'EOMES', 'RXRB', 'IRF3', 'ZBTB6', 'HSF1', 'ZNF350', 'ZNF341', 'ZNF354A', 'HESX1', 'HBP1', 'LYL1', 'ZNF282', 'NFE2L2', 'RARG', 'ARNTL', 'NPAS2', 'THAP1', 'MLXIP', 'TFDP1', 'SOX4', 'USF1', 'MLX', 'NFYA', 'ZNF134', 'STAT6', 'IRF4', 'ZBTB7B', 'ZNF250', 'NFATC2', 'FOXK1', 'AR', 'USF2', 'MTF1', 'VEZF1', 'ZNF140', 'ZNF317', 'KLF11', 'ELF4', 'ZNF85', 'ZSCAN16', 'MAFK', 'SREBF1', 'TBX19', 'PLAGL1', 'NR1H3', 'GLIS3', 'FOXJ2', 'OLIG1', 'IKZF4', 'ZFHX3', 'ESR2', 'CEBPA', 'SMAD1', 'ZNF232', 'IRF5', 'ZNF589', 'BATF3', 'MYBL2', 'CREB3L4'])

# %%
regulons_act_act.keys()
# Out:
# dict_keys(['ZNF436', 'CEBPB', 'GABPA', 'IRF3', 'TP53', 'MYC', 'MAFB', 'BCL11B', 'RELA', 'TCF12', 'RXRA', 'MAFG', 'GATA3', 'SP1', 'ZBTB4', 'E2F5', 'ZFHX3', 'SRF', 'PPARG', 'RFX4', 'ZSCAN26', 'TFCP2L1', 'RARB', 'KLF12', 'LEF1', 'SOX15', 'KLF4', 'MECOM', 'TBX18', 'MEF2C', 'PRRX1', 'PAX5', 'EBF3', 'MYBL2', 'CREB3L2', 'SPIC', 'NR2E3', 'RARA', 'ZBTB7C', 'MITF', 'TFAP2E', 'TP63', 'EBF1', 'RORA', 'CREB1', 'LYL1', 'BACH2', 'MYCN', 'NPAS3', 'ESRRG', 'DMRT1', 'HIVEP2', 'AR', 'HNF4G', 'CREB5', 'NFAT5', 'NFKB1', 'BCL11A', 'ARNTL2', 'NFATC2', 'SPI1', 'HIVEP3', 'CTCFL', 'ETV1', 'NFIB', 'ATF6', 'MEF2A', 'CUX1', 'ETV6', 'MEIS1', 'NR1H3', 'SOX4', 'ESR2', 'CREB3L3', 'FOXN3', 'RUNX2', 'GLIS1', 'KLF13', 'PAX3', 'ZNF418', 'IKZF3', 'HNF4A', 'ZKSCAN1', 'RFX2', 'ARNTL', 'CREM', 'HLX', 'NPAS2', 'FOXC1', 'CLOCK', 'ESR1', 'ERG', 'SP4', 'ELK3', 'SIM1', 'MLXIP', 'ZNF257', 'PROX1', 'SP140', 'ZBTB14', 'OSR2', 'PRDM1', 'GZF1', 'ZBTB7A', 'NPAS1', 'MLXIPL', 'ELF1', 'FOXP1', 'THRB', 'MEIS2', 'BBX', 'BHLHE40', 'ZEB1', 'TEAD1', 'ZNF680', 'RUNX1', 'ZNF331', 'PBX1', 'LHX4', 'ZNF317', 'TFEB', 'ETS1', 'OLIG1', 'TBX19', 'NR2F1', 'FOXO6', 'TFE3', 'RORB', 'FOSL2', 'ZNF85', 'HLF', 'TCF7L1', 'ZNF713', 'VDR', 'GLIS3', 'STAT1', 'FOXJ2', 'NRL', 'ETV7', 'ZNF41', 'ATF3', 'RREB1', 'PKNOX2', 'GLI2', 'ZSCAN31', 'TCF4', 'TFCP2', 'NFYA', 'UBP1', 'MAF', 'NR3C2', 'ESRRB', 'TBX15', 'IKZF1', 'PRDM4', 'NR6A1', 'EGR1', 'ZNF431', 'GCM1', 'ZNF816', 'IRF8', 'PAX6', 'E2F7', 'TFDP1', 'SMAD3', 'SOX8', 'E2F6', 'RUNX3', 'ATF5', 'IRF5', 'TAL2', 'POU6F2', 'NFATC1', 'LBX2', 'NFIX', 'ZNF75D', 'ZKSCAN3', 'OVOL2', 'PKNOX1', 'KLF9', 'ALX4', 'CEBPD', 'RBPJ', 'E2F8', 'MAX', 'PAX2', 'JUND', 'ZNF8', 'AHRR', 'IRF1', 'ZNF76', 'POU2F1', 'THRA', 'GLI3', 'ZNF394', 'ZNF589', 'EOMES', 'ETV5', 'ZNF282', 'ERF', 'HOXC5', 'ELF2', 'VENTX', 'ZNF263', 'ESRRA', 'FOSB', 'RFX1', 'HDX', 'MYBL1', 'HNF1A', 'STAT5B', 'CTCF', 'ELK1', 'GATA1', 'NR2F6', 'FLI1', 'NKX3-1', 'SIM2', 'ZNF549', 'KLF15', 'NFE2L2', 'SPIB', 'ZNF768', 'MXI1', 'E2F3', 'GRHL2', 'ZBED1', 'CEBPA', 'NR2C2', 'ZNF423', 'TFAP4', 'ZNF121', 'TCF7', 'XBP1', 'STAT3', 'NR1I3', 'RFX3', 'ZNF140', 'FOS', 'ZNF467', 'RFX7', 'NFIC', 'THAP11', 'HIVEP1', 'FOXN2', 'ZNF528', 'SOX10', 'SP2', 'CUX2', 'NHLH1', 'SMAD1', 'STAT4', 'PPARD', 'NR5A2', 'NR1I2', 'YY1', 'PAX7', 'ZNF264', 'PGR', 'IRF2', 'MAFA', 'HSF2', 'NFKB2', 'HOMEZ', 'ETV4', 'ZNF524', 'PBX4', 'RXRG', 'ATF2', 'TBX21', 'KLF7', 'SMAD2', 'VSX2', 'NFIL3', 'AHR', 'ZBTB16', 'JUN', 'NOBOX', 'REL', 'GMEB2', 'ZNF24', 'HIC1', 'TEAD4', 'DBP', 'STAT5A', 'ZNF322', 'E2F2', 'NR5A1', 'DDIT3', 'ZNF320', 'ZIC1', 'ZNF652', 'E2F4', 'LHX3', 'KLF16', 'PBX3', 'FOXK1', 'IRF4', 'E2F1', 'SP7', 'USF2', 'KLF3', 'MSC', 'NFE2', 'GATA2', 'POU2F2', 'HSF1', 'LMX1B', 'NR1H4', 'TAL1', 'SOX7', 'BHLHE41', 'EMX1', 'NFATC3', 'PRRX2', 'SIX5', 'MEF2D', 'HINFP', 'KLF10', 'MYB', 'POU5F1B', 'GFI1', 'MEOX1', 'CREB3L1', 'KLF2', 'NFIA', 'TCF7L2', 'POU2F3', 'BCL6', 'CREB3L4', 'ZNF784', 'E4F1', 'FOXD2', 'THAP1', 'ETV2', 'ETS2', 'HOXC4', 'MAZ', 'NR1H2', 'RFX8', 'JUNB', 'IRF9', 'ZNF136', 'TP73', 'HBP1', 'HOXA9', 'FOXK2', 'NRF1', 'HEY2', 'ZSCAN16', 'HEY1', 'ZNF324', 'NFYC', 'FOXO3', 'RELB', 'ETV3', 'SP100', 'NR3C1', 'ZNF134', 'ZNF708', 'PATZ1', 'ZNF382', 'SREBF1', 'SP3', 'RFX5', 'POU5F1', 'PPARA', 'MEIS3', 'JDP2', 'ZKSCAN4', 'RXRB', 'ATF7', 'ZNF329', 'ZNF148', 'VEZF1', 'ZBTB47', 'PAX8', 'EHF', 'TEF', 'HOXA1', 'FOXO1', 'ZNF250', 'SREBF2', 'STAT2', 'NFATC4', 'GLIS2', 'ATF4', 'TEAD3', 'EGR2', 'ZBTB7B', 'ZNF490', 'RORC', 'MLX', 'HEYL', 'RARG', 'HOXA6', 'POU4F1', 'BATF3', 'TGIF1', 'ONECUT3', 'TFDP2', 'CEBPE', 'HIF1A', 'FOSL1', 'ALX3', 'HNF1B', 'NFE2L1', 'PLAG1', 'ZNF628', 'MTF1', 'SP6', 'HOXB2', 'ZNF232', 'PBX2', 'ELF4', 'MGA', 'LHX2', 'CREBZF', 'BACH1', 'ZNF75A', 'ELK4', 'TGIF2', 'HESX1', 'MEF2B', 'ZBTB42', 'PURA', 'ATF1', 'ZNF502', 'ZNF274', 'NFYB', 'ZNF341', 'KLF6', 'HOXB6', 'ZNF586', 'ZNF143', 'HES7', 'GLI1', 'NR1D1', 'NR1D2', 'ZNF740', 'CREB3'])

# %%
percentage_overlapp_smallest_regulon = []
for TF in set(regulons_exp_exp.keys()).intersection(set(regulons_act_act.keys())):
    s = set(regulons_act_act[TF]).intersection(set(regulons_exp_exp[TF]))
    print(TF, s, len(s)/min(len(set(regulons_act_act[TF])), len(set(regulons_exp_exp[TF])) ) , min(len(set(regulons_act_act[TF])), len(set(regulons_exp_exp[TF])) ) )
    percentage_overlapp_smallest_regulon.append(len(s)/min(len(set(regulons_act_act[TF])), len(set(regulons_exp_exp[TF])) ))
# Out:
# HSF1 set() 0.0 10
# ZNF257 set() 0.0 15
# RBPJ set() 0.0 32
# ATF6 {'RNF180'} 0.043478260869565216 23
# ZNF589 set() 0.0 12
# EOMES set() 0.0 22
# JUNB {'BTG1'} 0.013513513513513514 74
# SRF {'LINC02484'} 0.034482758620689655 29
# PATZ1 {'KCNK1'} 0.038461538461538464 26
# SP140 {'PWRN4', 'MKRN3', 'PAPPA'} 0.1111111111111111 27
# NFAT5 {'LINC02237'} 0.045454545454545456 22
# HBP1 {'ARGLU1'} 0.03333333333333333 30
# ZNF431 {'LINC01720'} 0.05555555555555555 18
# IRF1 set() 0.0 13
# GABPA {'SLITRK4', 'KCNK1', 'TRAV8-5'} 0.08571428571428572 35
# MLXIP {'DAO'} 0.041666666666666664 24
# E2F4 {'MANEA-DT'} 0.03333333333333333 30
# PBX2 set() 0.0 14
# HOXB2 set() 0.0 12
# E2F3 set() 0.0 16
# KLF16 set() 0.0 13
# SMAD2 set() 0.0 31
# ZNF24 {'RNF180'} 0.058823529411764705 17
# ZNF232 set() 0.0 11
# SREBF2 set() 0.0 21
# EBF1 {'MS4A1', 'CCR6', 'SWAP70', 'HLA-DPB1', 'CD79B'} 0.046296296296296294 108
# TGIF1 set() 0.0 10
# ZFHX3 {'TNIK'} 0.07692307692307693 13
# ZNF282 set() 0.0 21
# GZF1 set() 0.0 13
# RUNX1 {'NRXN1'} 0.007407407407407408 135
# SP100 {'LINC02607'} 0.045454545454545456 22
# MAZ {'GNG3'} 0.045454545454545456 22
# BCL11B {'CD36', 'SNHG6', 'KYNU', 'SNX10', 'LY9', 'TC2N', 'KMT2A', 'MS4A6A', 'MCTP2', 'CTBP2', 'INPP5D', 'CDC14A', 'KIAA1755', 'NOL4L', 'RRP12', 'MAP3K8', 'LINC02848', 'ARHGAP26', 'LRRK2', 'LRRC8D', 'SYT1', 'SERINC5', 'PLEKHO1', 'CHST15', 'CD28', 'EVL', 'TBC1D9', 'TRIB1', 'UGT8', 'CCND2', 'TESPA1', 'LRP1', 'RILPL2', 'OXNAD1', 'CBLB', 'FCGR2A', 'PILRA', 'DAPK1', 'UBASH3A', 'TRIO', 'NADK', 'GRN', 'CD48', 'CTSZ', 'HLA-DRB1', 'STRBP', 'FES', 'PIP5K1B', 'PITPNC1', 'STMN3', 'PSAP', 'NCOR2', 'SAMD4A', 'ITK', 'SFI1', 'RPS24', 'CHD1', 'XYLT1', 'PBXIP1', 'GSN', 'PRKCH', 'ZEB1', 'PCAT1'} 0.14685314685314685 429
# MYBL2 set() 0.0 17
# CUX1 {'PBK'} 0.01020408163265306 98
# NR1D2 set() 0.0 10
# BCL6 {'SYT1', 'LINC02671'} 0.1 20
# TP53 set() 0.0 13
# IRF4 {'NDC80'} 0.034482758620689655 29
# KLF7 {'MANEA-DT'} 0.05 20
# CLOCK set() 0.0 24
# MGA set() 0.0 21
# FOXK1 set() 0.0 30
# KLF10 set() 0.0 16
# RARG set() 0.0 12
# MEF2A {'KCNJ3'} 0.018867924528301886 53
# TCF12 {'CNTN6', 'LINC02174'} 0.015503875968992248 129
# ELF4 set() 0.0 12
# IRF5 {'LINC02237'} 0.024390243902439025 41
# ZBTB7B set() 0.0 12
# TCF7 {'LINC02237', 'CDH8', 'TRDN', 'EIF4B'} 0.06557377049180328 61
# YY1 set() 0.0 53
# ELF2 {'LINC02607'} 0.017857142857142856 56
# NFIA set() 0.0 35
# EGR1 {'PRSS48'} 0.025 40
# KLF13 set() 0.0 83
# CREB3 set() 0.0 10
# FLI1 set() 0.0 67
# FOSB {'HDAC4', 'YME1L1', 'CHD1', 'SIK3', 'NUP98', 'MCL1', 'CWC25', 'C19orf44', 'KDM2A', 'RRP12'} 0.046948356807511735 213
# CEBPA set() 0.0 19
# KLF9 set() 0.0 19
# NFE2L2 set() 0.0 55
# NFIC {'CDH19'} 0.017241379310344827 58
# RXRB set() 0.0 21
# ARNTL {'ITGA9'} 0.020833333333333332 48
# SMAD3 {'CAHM'} 0.015384615384615385 65
# IRF2 set() 0.0 28
# NR1H3 set() 0.0 18
# ZNF263 {'LINC02327'} 0.043478260869565216 23
# ERF {'PRRC2C'} 0.02127659574468085 47
# SP2 {'PCDH7'} 0.034482758620689655 29
# NRL {'KCNIP4'} 0.0625 16
# REL {'TRAJ4'} 0.03125 32
# NFIL3 set() 0.0 10
# KLF3 set() 0.0 15
# ZNF394 {'OR11G2'} 0.1 10
# THRA set() 0.0 12
# THAP1 set() 0.0 28
# ZNF140 set() 0.0 24
# UBP1 set() 0.0 25
# RFX3 set() 0.0 64
# FOXJ2 set() 0.0 14
# HIVEP2 set() 0.0 63
# ELF1 {'CELF2'} 0.013513513513513514 74
# VEZF1 set() 0.0 15
# ZNF382 set() 0.0 10
# TBX19 set() 0.0 17
# ZNF264 {'PCDH7'} 0.047619047619047616 21
# JUN {'TRAV38-1'} 0.011494252873563218 87
# ESR1 {'DOLPP1', 'CNTLN'} 0.06060606060606061 33
# JUND set() 0.0 105
# ZNF549 set() 0.0 13
# RELB {'ARGLU1'} 0.02631578947368421 38
# STAT2 set() 0.0 15
# ATF2 set() 0.0 35
# SOX4 set() 0.0 19
# ZNF713 set() 0.0 17
# CUX2 {'AHI1'} 0.021739130434782608 46
# RFX7 set() 0.0 14
# HSF2 set() 0.0 23
# FOXO1 {'LINC01707'} 0.05263157894736842 19
# E2F5 {'CNTNAP5', 'AUTS2'} 0.06451612903225806 31
# NFIX set() 0.0 20
# IRF9 set() 0.0 17
# NFKB1 {'LINC01707', 'CCDC91', 'EQTN', 'GADL1', 'SILC1'} 0.07936507936507936 63
# TFEB set() 0.0 56
# CREM {'CCNE2'} 0.013888888888888888 72
# LEF1 {'ZNF609', 'SUPT3H', 'TRDN', 'MCTP2', 'LINC02237', 'LEF1-AS1', 'APOBEC3G', 'IFI44', 'PLXDC2', 'MS4A1', 'DGKG', 'DMXL1', 'PIK3CD', 'TESPA1', 'CDH8', 'OXNAD1', 'TGFBR2', 'SLC8A2', 'SNRK'} 0.14393939393939395 132
# NR3C1 {'LINC02227'} 0.014925373134328358 67
# ZNF628 set() 0.0 20
# ZNF652 set() 0.0 60
# ELK1 set() 0.0 27
# XBP1 {'P3H2-AS1'} 0.05 20
# SPIB {'SLC9A7'} 0.01818181818181818 55
# CEBPB set() 0.0 21
# MAX {'LINC00428', 'HLTF-AS1', 'COL4A6', 'LINC01641'} 0.038461538461538464 104
# ZSCAN16 set() 0.0 13
# NR1D1 set() 0.0 12
# ATF3 {'RGS2', 'ARHGAP26', 'AOAH', 'ATP1A1', 'RIPK2', 'XIST'} 0.05660377358490566 106
# RFX2 {'KCNK4'} 0.01818181818181818 55
# NFYA set() 0.0 14
# MAF set() 0.0 21
# TFCP2 set() 0.0 14
# GATA3 set() 0.0 43
# ZBTB16 {'COBL'} 0.038461538461538464 26
# ETV6 {'NCOA2', 'ARFGEF2', 'NAGK', 'EPSTI1', 'FGL1', 'PRDM6', 'STK40', 'MYO1A', 'RREB1', 'RYBP', 'BLVRA', 'ANKUB1'} 0.046153846153846156 260
# FOXN2 set() 0.0 29
# BBX {'ARGLU1', 'LINC02296'} 0.08333333333333333 24
# TCF7L2 {'RNF144B', 'PECAM1'} 0.14285714285714285 14
# PPARD set() 0.0 33
# ZNF75A set() 0.0 13
# GLIS3 {'GREB1L'} 0.06666666666666667 15
# HESX1 set() 0.0 13
# POU2F2 {'ITGA4'} 0.025 40
# ESRRA set() 0.0 55
# NFKB2 {'ARGLU1'} 0.016666666666666666 60
# DDIT3 set() 0.0 20
# E2F6 set() 0.0 31
# BHLHE40 {'KCNIP4'} 0.03571428571428571 28
# GMEB2 set() 0.0 30
# ZNF528 {'CDH8'} 0.07692307692307693 13
# PAX5 {'GNB5', 'BLK', 'TMEM156', 'KCNC3', 'BIRC3', 'LRRK2', 'BTLA', 'MICAL3', 'AUTS2', 'TC2N', 'CLCN4', 'TLR10', 'CAPZB', 'DGKZ', 'CHPT1', 'TNIK', 'IL6R', 'TRERF1'} 0.13636363636363635 132
# RREB1 {'PCDH7'} 0.017857142857142856 56
# FOXK2 set() 0.0 14
# CREB5 {'NCOA2', 'HDAC4', 'RBPJ', 'SNX10', 'TC2N', 'MAN1A1', 'PRKCD', 'OSBPL9', 'SNRPD2', 'RRP12', 'ATXN7', 'PLXDC2', 'PLEKHG2', 'LPAR1', 'SEMA4A', 'MZT2A', 'TFCP2', 'NUP214', 'RIN3', 'CEMP1', 'ARL15', 'MIR222HG', 'SENP2', 'AP3B1', 'LRP1', 'SLC25A37', 'LAP3', 'DAPK1', 'SSH1', 'ACOT9', 'NADK', 'RNF111', 'ATG3', 'IL16', 'RIPK2', 'FES', 'RREB1', 'FIG4', 'NCOR2', 'NFIC', 'PBRM1', 'PRPF8', 'GPD2', 'DTNBP1', 'IL6R'} 0.1965065502183406 229
# ZBED1 set() 0.0 15
# NFATC2 {'CX3CR1', 'NCALD'} 0.04081632653061224 49
# NR6A1 {'ERO1B', 'CEP55'} 0.11764705882352941 17
# SP3 {'PCDH7'} 0.023255813953488372 43
# ELK3 set() 0.0 50
# RUNX3 {'GRIK2', 'HLA-C', 'STARD6', 'MCTP2', 'ZMAT4'} 0.03676470588235294 136
# ZNF708 set() 0.0 16
# PPARA {'ADGRB3'} 0.08333333333333333 12
# ZBTB4 {'LINC02237'} 0.02631578947368421 38
# SP1 {'ARGLU1', 'NOVA1'} 0.043478260869565216 46
# ATF5 set() 0.0 16
# STAT5A set() 0.0 12
# KLF2 set() 0.0 18
# SMAD1 set() 0.0 15
# MECOM {'NRXN1'} 0.09090909090909091 11
# RFX5 set() 0.0 19
# LYL1 {'LINC01720'} 0.05555555555555555 18
# NFYB set() 0.0 11
# HIVEP1 set() 0.0 49
# AHR set() 0.0 53
# ZEB1 {'TRAV38-1', 'NAP1L1', 'PARD3', 'IL17RD'} 0.05263157894736842 76
# RFX1 {'KIAA0895'} 0.03225806451612903 31
# NR2F6 set() 0.0 12
# CREBZF set() 0.0 19
# BCL11A {'DERL3', 'FCHSD2', 'RUBCNL', 'CUX2'} 0.05263157894736842 76
# KLF12 {'SIRPB2', 'JCAD'} 0.047619047619047616 42
# RARA set() 0.0 29
# ZNF8 {'LINC02327'} 0.06666666666666667 15
# ZNF143 set() 0.0 25
# MLX set() 0.0 16
# FOSL1 set() 0.0 17
# ZNF75D {'LSAMP'} 0.047619047619047616 21
# IKZF3 set() 0.0 50
# KLF6 {'EIF1'} 0.07142857142857142 14
# PRDM1 {'KCNJ3'} 0.07692307692307693 13
# ZNF41 set() 0.0 16
# ZNF768 set() 0.0 10
# MXI1 {'TXNL4B', 'ACSS3', 'DPY19L2'} 0.024193548387096774 124
# NPAS2 set() 0.0 10
# MYBL1 {'KCNJ3', 'CDC7'} 0.06060606060606061 33
# ZNF680 set() 0.0 15
# SP4 {'PCDH7'} 0.021739130434782608 46
# FOS {'KIAA0100', 'EIF1', 'MCL1', 'TLE4'} 0.10810810810810811 37
# PRDM4 set() 0.0 25
# SPI1 {'ACAA1'} 0.030303030303030304 33
# ETS2 {'SLITRK4'} 0.03571428571428571 28
# OVOL2 {'ARGLU1', 'MEI4'} 0.09523809523809523 21
# BACH1 set() 0.0 14
# RXRA {'NCOA2', 'WAC', 'CSMD3', 'PBX1', 'SIL1', 'RYBP', 'APBB1IP', 'PRDM12', 'NALCN', 'RIN3', 'UGT8', 'LIPM', 'NR3C2', 'RAB12', 'KPNA4', 'CNTLN', 'UTRN', 'ADGRL4', 'FSIP2-AS1', 'RGS2', 'AQP4-AS1', 'LINC02426', 'LINC00677', 'CLDN10'} 0.09230769230769231 260
# ZNF274 {'GRIK2'} 0.08333333333333333 12
# HINFP {'ARGLU1'} 0.041666666666666664 24
# STAT1 {'GADL1', 'SERPINB5'} 0.05555555555555555 36
# ATF1 set() 0.0 16
# TFE3 set() 0.0 26
# CREB3L2 {'PBX1'} 0.016666666666666666 60
# IRF8 {'KCNIP4'} 0.02702702702702703 37
# CTCF {'PTN', 'COL4A6', 'GALNT17'} 0.02654867256637168 113
# ESR2 set() 0.0 18
# ZNF341 set() 0.0 13
# PBX3 set() 0.0 31
# ZNF134 set() 0.0 10
# ETV7 set() 0.0 17
# SREBF1 set() 0.0 19
# RUNX2 {'SUPT3H', 'GRIK2', 'P3H2-AS1', 'CUX2', 'ZMAT4', 'METTL24'} 0.05128205128205128 117
# NFYC set() 0.0 23
# PKNOX1 {'MANEA-DT', 'CAMKK1'} 0.044444444444444446 45
# TFAP4 set() 0.0 18
# AR {'SAMD12'} 0.07692307692307693 13
# STAT4 {'NCALD'} 0.06666666666666667 15
# BACH2 {'OXNAD1', 'CPPED1', 'LRRC8D', 'CLEC20A', 'LRRC2', 'BTG1'} 0.018867924528301886 318
# BATF3 set() 0.0 32
# USF2 set() 0.0 16
# ZNF136 set() 0.0 13
# NR2C2 set() 0.0 32
# ZNF317 {'CDH8'} 0.0625 16
# ETS1 {'HMGB1', 'DOCK10', 'DNAI1', 'LRBA', 'BTG1', 'SLC13A1', 'RPL12', 'KIF2A'} 0.035555555555555556 225
# ZNF121 {'LINC02671'} 0.05555555555555555 18
# ZNF148 set() 0.0 19
# ZNF250 set() 0.0 10
# TFDP2 set() 0.0 10
# MAFB {'IFITM3'} 0.009174311926605505 109
# E4F1 set() 0.0 21
# TBX21 set() 0.0 42
# KLF4 {'SIRPB2', 'CD36', 'PILRA', 'RBPJ', 'ATP1A1', 'RAB12', 'MS4A6A', 'TMEM144'} 0.17391304347826086 46
# CREB1 set() 0.0 67
# MITF set() 0.0 14
# ETV3 set() 0.0 30
# MAFG {'PWRN4', 'KCNIP4', 'MKRN3'} 0.08571428571428572 35
# OLIG1 set() 0.0 10
# NFATC1 {'WNT5B', 'DOCK1'} 0.06060606060606061 33
# ZBTB14 {'ARGLU1', 'FSIP2-AS1'} 0.08333333333333333 24
# MTF1 set() 0.0 29
# ZNF490 set() 0.0 16
# ZNF76 {'FSIP2-AS1', 'MEI4'} 0.0625 32
# STAT3 set() 0.0 79
# PURA {'IGLV1-47'} 0.05 20
# CEBPD {'HELZ', 'BLK', 'LRBA'} 0.0967741935483871 31
# NR1H2 set() 0.0 46
# POU2F1 set() 0.0 11
# ZNF85 set() 0.0 11
# JDP2 set() 0.0 30
# ZKSCAN1 set() 0.0 23
# ZNF467 {'CSMD3'} 0.06666666666666667 15
# TGIF2 set() 0.0 22
# NFE2 set() 0.0 20
# THAP11 {'MEI4'} 0.04 25
# ZNF784 set() 0.0 11
# ZNF740 set() 0.0 15
# HOMEZ set() 0.0 12
# HIVEP3 set() 0.0 71
# ZBTB7A {'FSIP2-AS1'} 0.05555555555555555 18
# ZNF329 set() 0.0 18
# ZNF586 set() 0.0 16
# NR3C2 {'SERINC5'} 0.014084507042253521 71
# ATF4 set() 0.0 21
# CREB3L4 set() 0.0 12
# PBX4 {'ARGLU1', 'LINC02607'} 0.1 20
# VENTX set() 0.0 10
# NFATC3 set() 0.0 49
# ZNF322 set() 0.0 15
# STAT5B set() 0.0 64
# HIF1A {'LINC01756'} 0.041666666666666664 24
# ELK4 set() 0.0 17
# MEF2D set() 0.0 54
# ATF7 set() 0.0 17
# IRF3 set() 0.0 21
# TFDP1 set() 0.0 31
# PAX8 set() 0.0 10
# MEF2C {'ARFGEF2', 'CD8A', 'TMEM268', 'THEMIS', 'IQSEC1', 'AKAP13', 'ANKRD13A', 'RASSF2', 'FGL1', 'PRKCH', 'EVL', 'CTSZ', 'TBC1D9', 'GNA12'} 0.08917197452229299 157
# ZNF524 set() 0.0 16
# TCF4 {'LDB3'} 0.06666666666666667 15
# MYC set() 0.0 35
# DBP set() 0.0 23
# NRF1 set() 0.0 21
# IKZF1 set() 0.0 64
# RELA set() 0.0 22
# FOXN3 {'CELF2', 'GNG3'} 0.030303030303030304 66
# FOSL2 {'YWHAB', 'C8orf34'} 0.03333333333333333 60
# ZNF324 {'PWRN4', 'MKRN3'} 0.15384615384615385 13
# ZNF331 {'HRNR'} 0.02127659574468085 47
# ZNF816 set() 0.0 10
# NFE2L1 set() 0.0 15
# ZKSCAN4 set() 0.0 23
# RORA {'PLXDC2', 'RPS6KA3', 'JCAD', 'CDC14A', 'CELF2'} 0.03496503496503497 143

# %%
sns.histplot(percentage_overlapp_smallest_regulon)
# Out:
# <Axes: ylabel='Count'>

# %%
# set up CollecTRI Bencjmark
path_CTRI            = '/scratch/gent/vo/000/gvo00027/projects/CBIGR/22JLR_ATAC_GRN_benchmark/GBM/omnipath/CollecTri_gene_names.csv'
CTRI_full, CTRI_full_filtered = prepareCollecTRIGoldStandard(path_CTRI, evidence_score=1)

# %%
TF_TG_interactions_binary_all_samples_sc_10x = {}
TF_TG_interactions_weight_all_samples_sc_10x = {}

samples = ['exp_exp', 'act_act']

TF_TG_interactions_binary_all_samples_sc_10x['exp_exp'] = TF_TG_interactions_binary_exp_exp
TF_TG_interactions_weight_all_samples_sc_10x['exp_exp'] = TF_TG_interactions_weighted_exp_exp

TF_TG_interactions_binary_all_samples_sc_10x['act_act'] = TF_TG_interactions_binary_act_act
TF_TG_interactions_weight_all_samples_sc_10x['act_act'] = TF_TG_interactions_weighted_act_act

# integrate
regulons_int, interactions_int, TF_TG_interactions_binary_int, TF_TG_interactions_weighted_int = rankIntegration([interactions_exp_exp, interactions_act_act])

TF_TG_interactions_binary_all_samples_sc_10x['int'] = TF_TG_interactions_binary_int
TF_TG_interactions_weight_all_samples_sc_10x['int'] = TF_TG_interactions_weighted_int
# Out:
# 9895

# %%
import sklearn as sk

# %%
# Now validate precision, recall and TP fraction per sample for different top k edges
# This can take a couple of minutes ! Relax and drink a coffee
# My early recall contains a logic error:
#       It works only because all of SCENICs scores are applied, also to the onces that scenic pruned with cis target.\
#       It therefore indicates the 'recall loss' due to the pruning of scenic, but not a recall
rc_sample_10x              = []
pc_sample_10x              = []
early_rc_sample_10x        = []
checked_range_sample_10x   = []

# all interactions in gold standard
no_interactions_CTRI = sum([sum(CTRI_full[x]['Status']) for x in CTRI_full])

# Calculations for 10x
for sample in samples:
    print('10x', sample)
    # Concatenate all regulons, and prepare them vor validation against the gold standard
    a1 = pd.concat(TF_TG_interactions_binary_all_samples_sc_10x[sample].values())
    a2 = pd.concat(TF_TG_interactions_weight_all_samples_sc_10x[sample].values())    
    b1 = pd.concat(CTRI_full.values()) 
    I_TG_b, I_Gold = intersect_pf(a1, b1)
    I_TG_w, I_Gold = intersect_pf(a2, b1)
    y_true  = np.array(I_Gold['Status'])
    y_pred  = np.array(I_TG_b['Status'])
    weights = np.array(I_TG_w['Status'])
    # Before sorting, we need to set all non-interaction values to zero !! Important to not bias SCENIC
    for i in range(len(weights)):
        if y_pred[i] == 0:
            weights[i] = 0
    # sort all interactions by the weight of their interactions
    list1, list2, list3 = zip(*sorted(zip(weights, y_true, y_pred), reverse=True))

    rc                = []
    pc                = []
    early_rc          = []
    checked_range_10x = []
    for i in [100,300,500,1000,3000,5000,10000,30000]:#,50000, len(list3)]:
        list3_filtered =   np.array(list(list3[0:i])+list(np.zeros(len(list3)-i)))         
        #rc.append(sk.metrics.recall_score(list2, list3_filtered))
        pc.append(sk.metrics.precision_score(list2, list3_filtered))    
        # Since the recall is artificially small: Percentage of Found interactions in top k edges
        early_rc.append(sk.metrics.confusion_matrix(list2, list3_filtered)[1,1]/sum(list2[0:i]))
        # Lets try a less biased version of recall: (problem: number of interaction is different between 10x and SMS)
        rc.append(sk.metrics.confusion_matrix(list2, list3_filtered)[1,1] / no_interactions_CTRI)
        
        
        checked_range_10x.append(i)
    rc_sample_10x.append(rc)
    pc_sample_10x.append(pc)
    early_rc_sample_10x.append(early_rc)
    checked_range_sample_10x.append(checked_range_10x)
# Out:
# 10x exp_exp
# 10x act_act

# %%
# Visualize benchmark resutls as heatmap
fig, axes = plt.subplots(1, 2, figsize=(20, 5),  sharey=False)

plt.subplots_adjust(hspace=0.5)
plt.ylim(0, 0.5)
axes[1].set_ylabel('top k edges')

df  = pd.DataFrame({samples[0]: pc_sample_10x[0], samples[1]: pc_sample_10x[1], samples[1]: pc_sample_10x[1]})
df2 = pd.DataFrame({samples[0]: rc_sample_10x[0], samples[1]: rc_sample_10x[1], samples[1]: rc_sample_10x[1]})
#sns.heatmap(df, yticklabels=[100,300,500,1000,3000,5000,10000,30000,50000, 'all'], ax=axes[0])
#sns.heatmap(df2, yticklabels=[100,300,500,1000,3000,5000,10000,30000,50000, 'all'], ax=axes[1])

#axes[0].set_position([axes[0].get_position().x0, axes[0].get_position().y0, axes[0].get_position().width * 0.95, axes[0].get_position().height])
axes[0].set_title("Precision", fontsize=14)
axes[1].set_title("Recall",fontsize=14)
axes[0].set_ylabel('Top k edges', rotation='vertical', fontsize=14)
axes[1].set_ylabel('Top k edges', rotation='vertical', fontsize=14)

sns.heatmap(df, yticklabels=[100,300,500,1000,3000,5000,10000,30000], ax=axes[0], vmin=0)
sns.heatmap(df2, yticklabels=[100,300,500,1000,3000,5000,10000,30000], ax=axes[1], vmin=0)
axes[0].set_ylabel('Top k edges', rotation='vertical', fontsize=14)
axes[1].set_ylabel('Top k edges', rotation='vertical', fontsize=14)
# col_index_pc = 2 * i
# col_index_rc = 2 * i + 1
# axes[col_index_pc].set_position([axes[col_index_pc].get_position().x0, axes[col_index_pc].get_position().y0, axes[col_index_pc].get_position().width * 0.95, axes[col_index_pc].get_position().height])
# axes[col_index_rc].set_position([axes[col_index_rc].get_position().x0 + 0.02, axes[col_index_rc].get_position().y0, axes[col_index_rc].get_position().width * 0.95, axes[col_index_rc].get_position().height])


# fig.savefig(result_folder + 'Benchmark_full_network_precision_recall.png',  dpi=300, format='png')
# fig.savefig(result_folder + 'Benchmark_full_network_precision_recall.svg',  dpi=300, format='svg')
# Out:
# Text(1066.1767676767674, 0.5, 'Top k edges')

# %%
pc_sample_10x
# Out:
# [[0.01,
#   0.02666666666666667,
#   0.022,
#   0.021,
#   0.018333333333333333,
#   0.017,
#   0.018250575468595858,
#   0.018250575468595858],
#  [0.05,
#   0.03,
#   0.024,
#   0.022,
#   0.016,
#   0.015,
#   0.014710799063858242,
#   0.014710799063858242]]
